# %% [markdown]
# ## CSVファイルを読み込んでみよう！

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/楽しい/programming_0920.csv")

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
#      TransactionID        Date                      Product  amount place
# 0                1    2/1/2024                   Grenadillo       2    CD
# 1                2   8/27/2024  Soup Knorr Chili With Beans       8    US
# 2                3   6/20/2024     Wine - Guy Sage Touraine       1    BR
# 3                4    5/1/2024            Cheese - Valancey       7    TH
# 4                5    8/8/2024     Pork - Tenderloin, Fresh       8    CN
# ..             ...         ...                          ...     ...   ...
# 995            996    7/3/2024               Pumpkin - Seed       9    US
# 996            997  12/12/2023            Ecolab - Ster Bac       8    US
# 997            998    1/1/2024             Tarragon - Fresh       4    CA
# 998            999   8/31/2024       Tart Shells - Sweet, 2       9    FR
# 999           1000   4/25/2024            Garlic - Elephant       3    DE
#
# [1000 rows x 5 columns]

# %%
df

# %% [markdown]
# 国（place）が「US」のデータのみを抽出

# %% [markdown]
# 2024年5月から2024年8月のデータを抽出

# %% [markdown]
# placeが「US」でかつamountが5以上のデータを抽出

# %% [markdown]
# 1. 月別の売上金額の集計

# %%
df['Month'] = df['Date'].dt.to_period('M')
monthly_sales = df.groupby('Month')['amount'].sum().reset_index()

# %% [markdown]
#  2. 商品別の販売数量の集計

# %% [markdown]
# 3. 国別の販売数量の集計

# %% [markdown]
# 4. 商品ごとの平均販売数量の分析

# %% [markdown]
# 5. 最高・最低売上を記録した商品

# %% [markdown]
# 6. 商品ごとの売上割合
